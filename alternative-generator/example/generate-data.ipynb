# %%
from alternative_generator import AlternativeGenerator

# %%
# Пример использования
for i in range(100):
    generator = AlternativeGenerator(
        num_criteria=8,
        num_alternatives=10,
        abs_ratio=0.7,
        abs_value_range=(-30, 50),
        ord_value_range=8,
        abs_distribution="uniform",
        ord_distribution="uniform",
        avg_group_size=2,
        group_size_std=1,
        fuzzy_numbers=True,
    )
    generator.generate_criteria()
    alternatives = generator.generate_alternatives()
    preferences = generator.generate_preferences()
    generator.export_to_json(f"data/test{i}.json")
# Out:
# JSON файл сохранен как data/test0.json
# JSON файл сохранен как data/test1.json
# JSON файл сохранен как data/test2.json
# JSON файл сохранен как data/test3.json
# JSON файл сохранен как data/test4.json
# JSON файл сохранен как data/test5.json
# JSON файл сохранен как data/test6.json
# JSON файл сохранен как data/test7.json
# JSON файл сохранен как data/test8.json
# JSON файл сохранен как data/test9.json
# JSON файл сохранен как data/test10.json
# JSON файл сохранен как data/test11.json
# JSON файл сохранен как data/test12.json
# JSON файл сохранен как data/test13.json
# JSON файл сохранен как data/test14.json
# JSON файл сохранен как data/test15.json
# JSON файл сохранен как data/test16.json
# JSON файл сохранен как data/test17.json
# JSON файл сохранен как data/test18.json
# JSON файл сохранен как data/test19.json
# JSON файл сохранен как data/test20.json
# JSON файл сохранен как data/test21.json
# JSON файл сохранен как data/test22.json
# JSON файл сохранен как data/test23.json
# JSON файл сохранен как data/test24.json
# JSON файл сохранен как data/test25.json
# JSON файл сохранен как data/test26.json
# JSON файл сохранен как data/test27.json
# JSON файл сохранен как data/test28.json
# JSON файл сохранен как data/test29.json
# JSON файл сохранен как data/test30.json
# JSON файл сохранен как data/test31.json
# JSON файл сохранен как data/test32.json
# JSON файл сохранен как data/test33.json
# JSON файл сохранен как data/test34.json
# JSON файл сохранен как data/test35.json
# JSON файл сохранен как data/test36.json
# JSON файл сохранен как data/test37.json
# JSON файл сохранен как data/test38.json
# JSON файл сохранен как data/test39.json
# JSON файл сохранен как data/test40.json
# JSON файл сохранен как data/test41.json
# JSON файл сохранен как data/test42.json
# JSON файл сохранен как data/test43.json
# JSON файл сохранен как data/test44.json
# JSON файл сохранен как data/test45.json
# JSON файл сохранен как data/test46.json
# JSON файл сохранен как data/test47.json
# JSON файл сохранен как data/test48.json
# JSON файл сохранен как data/test49.json
# JSON файл сохранен как data/test50.json
# JSON файл сохранен как data/test51.json
# JSON файл сохранен как data/test52.json
# JSON файл сохранен как data/test53.json
# JSON файл сохранен как data/test54.json
# JSON файл сохранен как data/test55.json
# JSON файл сохранен как data/test56.json
# JSON файл сохранен как data/test57.json
# JSON файл сохранен как data/test58.json
# JSON файл сохранен как data/test59.json
# JSON файл сохранен как data/test60.json
# JSON файл сохранен как data/test61.json
# JSON файл сохранен как data/test62.json
# JSON файл сохранен как data/test63.json
# JSON файл сохранен как data/test64.json
# JSON файл сохранен как data/test65.json
# JSON файл сохранен как data/test66.json
# JSON файл сохранен как data/test67.json
# JSON файл сохранен как data/test68.json
# JSON файл сохранен как data/test69.json
# JSON файл сохранен как data/test70.json
# JSON файл сохранен как data/test71.json
# JSON файл сохранен как data/test72.json
# JSON файл сохранен как data/test73.json
# JSON файл сохранен как data/test74.json
# JSON файл сохранен как data/test75.json
# JSON файл сохранен как data/test76.json
# JSON файл сохранен как data/test77.json
# JSON файл сохранен как data/test78.json
# JSON файл сохранен как data/test79.json
# JSON файл сохранен как data/test80.json
# JSON файл сохранен как data/test81.json
# JSON файл сохранен как data/test82.json
# JSON файл сохранен как data/test83.json
# JSON файл сохранен как data/test84.json
# JSON файл сохранен как data/test85.json
# JSON файл сохранен как data/test86.json
# JSON файл сохранен как data/test87.json
# JSON файл сохранен как data/test88.json
# JSON файл сохранен как data/test89.json
# JSON файл сохранен как data/test90.json
# JSON файл сохранен как data/test91.json
# JSON файл сохранен как data/test92.json
# JSON файл сохранен как data/test93.json
# JSON файл сохранен как data/test94.json
# JSON файл сохранен как data/test95.json
# JSON файл сохранен как data/test96.json
# JSON файл сохранен как data/test97.json
# JSON файл сохранен как data/test98.json
# JSON файл сохранен как data/test99.json
